# %%
import pandas as pd

# %%
import pandas as pd

# Load the first CSV file into a DataFrame
df1 = pd.read_csv('customer.csv')

# Load the second CSV file into another DataFrame
df2 = pd.read_csv('loan_data.csv')

# Concatenate the two DataFrames along the rows (axis=0)
combined_df = pd.concat([df1, df2], ignore_index=True)

# Save the combined DataFrame to a new CSV file
# combined_df.to_csv('combined_file.csv', index=False)

# %%
df2
# Out:
#      customer_id  loan_id  loan_amount  tenure  interest_rate  \
# 0              1     7798       900000     138          17.92
# 1              2     5607       400000      81          13.16
# 2              2     3957       200000      84          14.34
# 3              3     1313       100000     132          17.74
# 4              3     3050       500000      78           8.86
# ..           ...      ...          ...     ...            ...
# 777          299     5432       300000     180          14.37
# 778          299     9223       800000       6          11.66
# 779          300     9268       600000     162          14.34
# 780          300     6414       800000      84          11.51
# 781          300     4873       700000      45          13.75
#
#      monthly_repayment_emi  emis_paid_on_time approval_date    end_date
# 0                    39978                 86    08-11-2021  08-05-2033
# 1                    10369                 64    20-03-2017  20-12-2023
# ...

# %%
df1
# Out:
#      customer_id first_name  last_name  age  phone_number  monthly_income  \
# 0              1      Aaron     Garcia   63    9629317944           50000
# 1              2      Abbey   Gonzalez   20    9278790909           33000
# 2              3      Abbie  Rodrigues   47    9775988997          193000
# 3              4       Abby  Fernandez   60    9612343117          117000
# 4              5      Abdul      Lopez   40    9175345317          219000
# ..           ...        ...        ...  ...           ...             ...
# 295          296      Ardis   Domenech   56    9757942407           35000
# 296          297     Ardith     Zapata   40    9249491764           94000
# 297          298     Aretha      Riera   61    9124680892          188000
# 298          299    Argelia   Saavedra   30    9614182220           85000
# 299          300  Argentina     Toledo   46    9506356490          112000
#
#      approved_limit
# 0           4500000
# 1           1400000
# ...

# %%
df2['id']=df2['customer_id']

# %%
df1['id']=df1['customer_id']

# %%
df1.to_csv('customerdata.csv', index=False)

# %%
df2.to_csv('loandata.csv', index=False)
